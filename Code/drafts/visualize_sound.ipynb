# %%
import os
import wave as we
import numpy as np
import matplotlib.pyplot as plt 

def wavread(path):
    wavfile =  we.open(path,"rb")
    params = wavfile.getparams()
    framesra,frameswav= params[2],params[3]
    nchannels, sampwidth, framesra, frameswav = params[:4]

    datawav = wavfile.readframes(frameswav)
    wavfile.close()
    datause = np.fromstring(datawav,dtype = np.short)

    if nchannels == 2:
        datause.shape = -1,2
        datause = datause[:, 0]
    datause = datause.T
    time = np.arange(0, frameswav) * (1.0/framesra)
    return datause,time,nchannels

def main(path):
    # path = sys.argv[1]
    wavdata,wavtime,_ = wavread(path)

    plt.figure(figsize=(20, 5))

    plt.plot(wavtime,wavdata,color = 'green')
    plt.xlabel('Time')
    plt.ylabel('Amplitude')

    plt.show()

# %%
AUDIO_PATH = "D:\\14183\\Desktop"
processed = os.path.join(AUDIO_PATH, "return1_Vocals.wav")
main(processed)
# Out:
# D:\14183\ProgramData\Anaconda3\envs\ind\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead

# %%
origin = os.path.join(AUDIO_PATH, "return1.wav")
main(origin)
# Out:
# D:\14183\ProgramData\Anaconda3\envs\ind\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead

# %%
normalized = os.path.join(AUDIO_PATH, "return1-normalized_Vocals.wav")
main(normalized)
# Out:
# D:\14183\ProgramData\Anaconda3\envs\ind\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead

# %%
AUDIO_PATH = "D:\\14183\\Desktop"
processed = os.path.join(AUDIO_PATH, "return1_Vocals.wav")
main(processed)
# Out:
# D:\14183\ProgramData\Anaconda3\envs\ind\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead

# %%
AUDIO_PATH = "D:\\14183\\Desktop"
processed = os.path.join(AUDIO_PATH, "return1_Vocals.wav")
main(processed)
# Out:
# D:\14183\ProgramData\Anaconda3\envs\ind\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead

# %%
vocal_normalized = os.path.join(AUDIO_PATH, "return1_Vocals-normalized.wav")
main(vocal_normalized)
# Out:
# D:\14183\ProgramData\Anaconda3\envs\ind\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
